# %%
# !pip install update gdown

# downloading the annotaions
# !gdown --id 1M-yNQ_rj-sPUFqVJ7Ivw92_yel4U8y8V
# !unzip "/content/2023-05-14-09-02-05_project_annotation_wk1.zip"

# installing essential requirements
# !sudo apt-get install tesseract-ocr
# !apt-get install poppler-utils
# !pip install transformers
# !pip install pdf2image
# !pip install pytesseract
# !pip install "unstructured[local-inference]"
# !pip install layoutparser[tesseract]
# !pip install PyMuPDF

# downloading one pdf (typed)
# !gdown --id "1ZhMHDaOWz0FEfDrDEKB7e0pM0Vnzs6I5"

# download code
# !gdown --id 1zzoEqHSh7yA7S9KCKtbjYAl1FlWYyumB
# !unzip "/content/structued_pdf_data_extraction.zip"
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1zzoEqHSh7yA7S9KCKtbjYAl1FlWYyumB
# To: /content/structued_pdf_data_extraction.zip
# 100% 9.40k/9.40k [00:00<00:00, 42.5MB/s]
# Archive:  /content/structued_pdf_data_extraction.zip
#   inflating: alab_reader.py
#   inflating: align_pdfs.py
#   inflating: pdf_parser.py
#   inflating: tree.py
#   inflating: utils.py

# %%
from align_pdfs import Align_Pdfs
from alab_reader import AlabReader
from pdf_parser import Pdf_Parser
import warnings

# Filter all warnings
warnings.filterwarnings('ignore')

Align_Pdfs.get_aligned_imgs_with_pdf(
    "/content/1 - Joshua - Scanned .pdf",
    "/content/images",
    "/content/scanned_images",
    "/content/aligned_images"
)

alab = AlabReader(filename='completions.csv', images_root="/content/aligned_images")
parser = Pdf_Parser(doc_type= "typed")

alab.data_to_pages()
alab.define_related_classes()
alab.sync_multipage_classes()

parser.process_pdf(alab.pages)
parser.post_processing(alab.all_rels, alab.all_from_ids, alab.all_to_ids )

parser.extract_structure_json(path_to_save_json = "pdf_structure.json")

parser.tree.tree_to_json(parser.tree.root)
# Out:
# {'root': {'boundaries': {'left': 'Seller',
#    'right': 'Neighbour',
#    'rear': 'Seller',
#    'front': 'Not known',
#    'areIrregular': 'Ownership of irregular boundaries shared equally between neighbours.',
#    'haveBoundaryFeaturesMoved': {'details': 'Seller is aware of boundary feature moved by natural causes.',
#     'yesNo': 'Yes'},
#    'adjacentLandIncluded': {'yesNo': 'Yes',
#     'details': 'Seller purchased adjacent land for development purposes.'},
#    'propertyOverhang': {'yesNo': 'Yes',
#     'details': 'The cellar extends under the boundary of the neighbouring property.'},
#    'partyWallAct': {'yesNo': 'Enclosed',
#     'details': 'No work has been carried out or agreed under the Party Wall etc. Act 1996.'}},
#   'disputesAndComplaints': {'hasDisputesAndComplaints': {'yesNo': 'Yes',
#     'details': 'Complaint from neighbour over noise disturbance; issue resolved.'},
#    'leadToDisputes': {'yesNo': 'Yes',
# ...
